# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")

# %%
df2 = pd.read_excel("Fortaleza.xlsx")

# %%
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df1
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 0    Aracaju 2018-01-01  142.00  1520.0   1.0
# 1    Aracaju 2018-01-01   14.21  1522.0   6.0
# 2    Aracaju 2018-01-01   71.55  1520.0   1.0
# 3    Aracaju 2018-01-01     NaN  1521.0   7.0
# 4    Aracaju 2018-01-01     NaN  1522.0   8.0
# ..       ...        ...     ...     ...   ...
# 125  Aracaju 2018-01-01   15.62  1522.0   2.0
# 126  Aracaju 2018-01-01   13.41  1520.0   7.0
# 127  Aracaju 2018-01-01   33.12  1522.0   9.0
# 128  Aracaju 2018-01-01   37.49  1521.0   2.0
# 129  Aracaju 2018-01-01   13.70  1522.0   6.0
#
# [130 rows x 5 columns]

# %%
df
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 0     Aracaju 2018-01-01  142.00  1520.0   1.0
# 1     Aracaju 2018-01-01   14.21  1522.0   6.0
# 2     Aracaju 2018-01-01   71.55  1520.0   1.0
# 3     Aracaju 2018-01-01     NaN  1521.0   7.0
# 4     Aracaju 2018-01-01     NaN  1522.0   8.0
# ..        ...        ...     ...     ...   ...
# 235  Salvador 2019-01-03   41.84  1034.0   1.0
# 236  Salvador 2019-01-03  126.29  1035.0   3.0
# 237  Salvador 2019-01-03   38.06  1036.0   3.0
# 238  Salvador 2019-01-03  139.64  1035.0   1.0
# 239  Salvador 2019-01-03  161.41  1037.0   3.0
#
# [894 rows x 5 columns]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00  1520.0   1.0
# 1  Aracaju 2018-01-01   14.21  1522.0   6.0
# 2  Aracaju 2018-01-01   71.55  1520.0   1.0
# 3  Aracaju 2018-01-01     NaN  1521.0   7.0
# 4  Aracaju 2018-01-01     NaN  1522.0   8.0

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84  1034.0   1.0
# 236  Salvador 2019-01-03  126.29  1035.0   3.0
# 237  Salvador 2019-01-03   38.06  1036.0   3.0
# 238  Salvador 2019-01-03  139.64  1035.0   1.0
# 239  Salvador 2019-01-03  161.41  1037.0   3.0

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 92      Recife 2019-01-01  163.02   981.0   4.0
# 3    Fortaleza 2019-02-10   20.95  1004.0   6.0
# 10     Aracaju 2019-01-01   42.34  1522.0   6.0
# 115  Fortaleza 2019-03-02   12.23   981.0   3.0
# 88   Fortaleza 2019-01-01   68.60  1004.0   6.0

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID           float64
# Qtde             float64
# dtype: object

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID           float64
# Qtde             float64
# dtype: object

# %%
df["LojaID"]=df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde             float64
# dtype: object

# %%
df.isnull()
# Out:
#      Cidade   Data  Vendas  LojaID   Qtde
# 0     False  False   False   False  False
# 1     False  False   False   False  False
# 2     False  False   False   False  False
# 3     False  False    True   False  False
# 4     False  False    True   False  False
# ..      ...    ...     ...     ...    ...
# 235   False  False   False   False  False
# 236   False  False   False   False  False
# 237   False  False   False   False  False
# 238   False  False   False   False  False
# 239   False  False   False   False  False
#
# [894 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    2
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Vendas"].fillna(df["Vendas"].mean(),inplace = True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data      Vendas  LojaID  Qtde     Receita
# 0  Aracaju 2018-01-01  142.000000  1520.0   1.0  142.000000
# 1  Aracaju 2018-01-01   14.210000  1522.0   6.0   85.260000
# 2  Aracaju 2018-01-01   71.550000  1520.0   1.0   71.550000
# 3  Aracaju 2018-01-01  122.855863  1521.0   7.0  859.991043
# 4  Aracaju 2018-01-01  122.855863  1522.0   8.0  982.846906

# %%
df["Receita"].max()
# Out:
# 3544.0

# %%
df["Receita"].min()
# Out:
# 3.34

# %%
df.nlargest(5,"Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0  853.0   4.0   3544.0
# 51  Natal 2018-01-21   859.0  852.0   4.0   3436.0
# 55  Natal 2019-01-08   859.0  854.0   4.0   3436.0
# 30  Natal 2018-10-02   856.0  853.0   4.0   3424.0
# 41  Natal 2018-05-20   835.0  852.0   4.0   3340.0

# %%
df.nsmallest(5,"Receita")
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34  1522.0   1.0     3.34
# 65     Recife 2019-01-01    4.01   981.0   1.0     4.01
# 92      Natal 2019-01-02    4.57  1035.0   1.0     4.57
# 92   Salvador 2019-01-01    4.57  1035.0   1.0     4.57
# 95      Natal 2019-01-02    5.13  1035.0   1.0     5.13

# %%
df.nsmallest(5,"Receita")["Data"].unique()
# Out:
# array(['2018-01-01T00:00:00.000000000', '2019-01-01T00:00:00.000000000',
#        '2019-01-02T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       50373.937948
# Fortaleza     37913.970000
# Natal        167227.520000
# Recife        51936.510000
# Salvador      40596.730000
# Name: Receita, dtype: float64

# %%
df.nsmallest(10,"Receita")["Cidade"].unique()
# Out:
# array(['Aracaju', 'Recife', 'Natal', 'Salvador'], dtype=object)

# %%
df.nsmallest(10,"Receita")
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34  1522.0   1.0     3.34
# 65     Recife 2019-01-01    4.01   981.0   1.0     4.01
# 92      Natal 2019-01-02    4.57  1035.0   1.0     4.57
# 92   Salvador 2019-01-01    4.57  1035.0   1.0     4.57
# 95      Natal 2019-01-02    5.13  1035.0   1.0     5.13
# 95   Salvador 2019-01-01    5.13  1035.0   1.0     5.13
# 161     Natal 2019-01-02    5.80  1036.0   1.0     5.80
# 161  Salvador 2019-01-02    5.80  1036.0   1.0     5.80
# 216     Natal 2019-01-02    5.82  1035.0   1.0     5.82
# 216  Salvador 2019-01-02    5.82  1035.0   1.0     5.82

# %%
df.nsmallest(10,"Receita").groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju      3.34
# Natal       21.32
# Recife       4.01
# Salvador    21.32
# Name: Receita, dtype: float64

# %%
df.nlargest(10,"Receita").groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Natal    33356.0
# Name: Receita, dtype: float64

# %%
df.nlargest(10,"Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita
# 7   Natal 2019-03-18   886.0  853.0   4.0   3544.0
# 51  Natal 2018-01-21   859.0  852.0   4.0   3436.0
# 55  Natal 2019-01-08   859.0  854.0   4.0   3436.0
# 30  Natal 2018-10-02   856.0  853.0   4.0   3424.0
# 41  Natal 2018-05-20   835.0  852.0   4.0   3340.0
# 10  Natal 2018-10-27   828.0  852.0   4.0   3312.0
# 38  Natal 2018-02-25   828.0  852.0   4.0   3312.0
# 69  Natal 2019-03-24   817.0  852.0   4.0   3268.0
# 62  Natal 2018-02-10   793.0  854.0   4.0   3172.0
# 52  Natal 2018-04-27   778.0  854.0   4.0   3112.0

# %%
df.dtypes
# Out:
# Cidade             object
# Data       datetime64[ns]
# Vendas            float64
# LojaID             object
# Qtde              float64
# Receita           float64
# dtype: object

# %%
df["Data"]=df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde       float64
# Receita    float64
# dtype: object

# %%
df.sample(10)
# Out:
#         Cidade       Data      Vendas  LojaID  Qtde      Receita
# 136      Natal 2019-01-02   13.810000  1036.0   1.0    13.810000
# 68       Natal 2018-06-22  274.000000   852.0   3.0   822.000000
# 105  Fortaleza 2019-01-01  174.660000  1004.0   1.0   174.660000
# 35      Recife 2019-01-01  148.900000   983.0   1.0   148.900000
# 213   Salvador 2019-01-02   42.120000  1035.0   1.0    42.120000
# 4      Aracaju 2018-01-01  122.855863  1522.0   8.0   982.846906
# 159      Natal 2019-01-02  172.520000  1035.0   1.0   172.520000
# 43    Salvador 2019-01-01   12.210000  1034.0   1.0    12.210000
# 75      Recife 2019-01-01  170.290000   981.0   8.0  1362.320000
# 103     Recife 2019-01-01   41.650000   982.0   3.0   124.950000

# %%
df["Data"]=pd.to_datetime(df["Data"])

# %%
df.head()
# Out:
#     Cidade       Data      Vendas  LojaID  Qtde     Receita
# 0  Aracaju 2018-01-01  142.000000  1520.0   1.0  142.000000
# 1  Aracaju 2018-01-01   14.210000  1522.0   6.0   85.260000
# 2  Aracaju 2018-01-01   71.550000  1520.0   1.0   71.550000
# 3  Aracaju 2018-01-01  122.855863  1521.0   7.0  859.991043
# 4  Aracaju 2018-01-01  122.855863  1522.0   8.0  982.846906

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    119802.217948
# 2019    228246.450000
# Name: Receita, dtype: float64

# %%
df.nlargest(10,"Receita").groupby(["Cidade" , df.nlargest(10,"Receita")["Data"].dt.year])["Receita"].sum()
# Out:
# Cidade  Data
# Natal   2018    23108.0
#         2019    10248.0
# Name: Receita, dtype: float64

# %%
df.nsmallest(50,"Receita").groupby([df.nsmallest(50,"Receita")["Cidade"] , df.nsmallest(50,"Receita")["Data"].dt.year])["Receita"].sum()
# Out:
# Cidade     Data
# Aracaju    2018     24.19
#            2019     12.16
# Fortaleza  2019     10.68
# Natal      2019    148.04
# Recife     2019     15.45
# Salvador   2019    241.88
# Name: Receita, dtype: float64

# %%
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 118   Aracaju 2018-01-01    3.34  1522.0   1.0     3.34
# 65     Recife 2019-01-01    4.01   981.0   1.0     4.01
# 92      Natal 2019-01-02    4.57  1035.0   1.0     4.57
# 92   Salvador 2019-01-01    4.57  1035.0   1.0     4.57
# 95      Natal 2019-01-02    5.13  1035.0   1.0     5.13
# 95   Salvador 2019-01-01    5.13  1035.0   1.0     5.13
# 161     Natal 2019-01-02    5.80  1036.0   1.0     5.80
# 161  Salvador 2019-01-02    5.80  1036.0   1.0     5.80
# 216     Natal 2019-01-02    5.82  1035.0   1.0     5.82
# 216  Salvador 2019-01-02    5.82  1035.0   1.0     5.82

# %%
df["Ano da Venda"]=df["Data"].dt.year

# %%
df.sample(10)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da Venda
# 124   Aracaju 2018-01-01  139.64  1522.0   5.0   698.20          2018
# 53   Salvador 2019-01-01   39.50  1035.0   3.0   118.50          2019
# 103     Natal 2019-01-02  191.60  1034.0   1.0   191.60          2019
# 214  Salvador 2019-01-02   54.94  1036.0   2.0   109.88          2019
# 43     Recife 2019-01-01   22.29   983.0   7.0   156.03          2019
# 90    Aracaju 2018-01-01   16.27  1522.0   1.0    16.27          2018
# 1    Salvador 2018-01-01   19.02  1034.0   3.0    57.06          2018
# 65      Natal 2019-04-05  292.00   852.0   2.0   584.00          2019
# 15     Recife 2019-01-01    7.45   981.0   2.0    14.90          2019
# 38      Natal 2018-02-25  828.00   852.0   4.0  3312.00          2018

# %%
df["Mês da Venda"],df["Dia da Venda"] = (df["Data"].dt.month,df["Data"].dt.day )

# %%
df.head()
# Out:
#     Cidade       Data      Vendas  LojaID  Qtde     Receita  Ano da Venda  \
# 0  Aracaju 2018-01-01  142.000000  1520.0   1.0  142.000000          2018
# 1  Aracaju 2018-01-01   14.210000  1522.0   6.0   85.260000          2018
# 2  Aracaju 2018-01-01   71.550000  1520.0   1.0   71.550000          2018
# 3  Aracaju 2018-01-01  122.855863  1521.0   7.0  859.991043          2018
# 4  Aracaju 2018-01-01  122.855863  1522.0   8.0  982.846906          2018
#
#    Mês da Venda  Dia da Venda
# 0             1             1
# 1             1             1
# 2             1             1
# 3             1             1
# 4             1             1

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da Venda  \
# 125    Aracaju 2018-01-01   15.62  1522.0   2.0    31.24          2018
# 59     Aracaju 2018-01-01   15.07  1523.0   7.0   105.49          2018
# 112     Recife 2019-03-02  133.59   982.0   1.0   133.59          2019
# 21   Fortaleza 2019-01-01   40.63  1004.0   3.0   121.89          2019
# 97      Recife 2019-01-01  153.04   983.0   4.0   612.16          2019
# 101    Aracaju 2018-01-01   16.62  1520.0   9.0   149.58          2018
# 123   Salvador 2019-03-02  127.45  1036.0   3.0   382.35          2019
# 5     Salvador 2019-01-01  179.20  1037.0   3.0   537.60          2019
# 142   Salvador 2019-01-02    7.12  1034.0   1.0     7.12          2019
# 36    Salvador 2019-01-01    9.67  1037.0   1.0     9.67          2019
#
#      Mês da Venda  Dia da Venda
# 125             1             1
# 59              1             1
# 112             3             2
# 21              1             1
# ...

# %%
df["LojaID"].value_counts(ascending = False)
# Out:
# 1036.0    117
# 1035.0    112
# 1037.0    101
# 1034.0     67
# 983.0      65
# 982.0      44
# 1522.0     41
# 1520.0     39
# 980.0      36
# 981.0      31
# 1005.0     30
# 1002.0     30
# 852.0      29
# 1523.0     29
# 1004.0     28
# 854.0      28
# 853.0      26
# 1521.0     21
# 1003.0     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending = False).plot.bar()

# %%
df["LojaID"].value_counts(ascending = False).plot.barh()

# %%
df["LojaID"].value_counts(ascending = True).plot.barh();

# %%
df.nsmallest(50,"Receita").groupby([df.nsmallest(50,"Receita")["Cidade"] , df.nsmallest(50,"Receita")["Data"].dt.year])["Receita"].sum().plot.pie()

# %%
df.nsmallest(50,"Receita").groupby([df.nsmallest(50,"Receita")["Cidade"] , df.nsmallest(50,"Receita")["Data"].dt.year])["Receita"].sum()
# Out:
# Cidade     Data
# Aracaju    2018     24.19
#            2019     12.16
# Fortaleza  2019     10.68
# Natal      2019    148.04
# Recife     2019     15.45
# Salvador   2019    241.88
# Name: Receita, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
vargraf = df.nsmallest(50,"Receita").groupby([df.nsmallest(50,"Receita")["Cidade"] , df.nsmallest(50,"Receita")["Data"].dt.year])["Receita"].sum()

# %%
vargraf
# Out:
# Cidade     Data
# Aracaju    2018     24.19
#            2019     12.16
# Fortaleza  2019     10.68
# Natal      2019    148.04
# Recife     2019     15.45
# Salvador   2019    241.88
# Name: Receita, dtype: float64

# %%
vargraf.plot.bar(title = "Receita por Cidade/Ano",color="red")
plt.xlabel("Cidade/Ano")
plt.ylabel("Receita");

# %%
plt.style.use('ggplot')

# %%
vargraf.plot.bar(title = "Receita por Cidade/Ano",color="red")
plt.xlabel("Cidade/Ano")
plt.ylabel("Receita")
plt.legend();

# %%
plt.hist(vargraf, color='magenta')
plt.title("Receitas de vendas")
plt.xlabel("Cidade/Ano")
plt.ylabel("Receita");
